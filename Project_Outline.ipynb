# %% [markdown]
# Big sales prediction

# %% [markdown]
# -------------

# %% [markdown]
# ## **Objective**

# %% [markdown]
# Big Sales Prediction using Random Forest Regressor

# %% [markdown]
# ## **Data Source**

# %% [markdown]
# ## **Import Library**

# %%
import panda as pd
import numpy as np

# %% [markdown]
# ## **Import Data**

# %%
df = pd.read_csv(r'https://github.com/YBIFoundation/Dataset/blob/main/Big%20Sales%20Data.csv')

# %% [markdown]
# ## **Describe Data**

# %%
df.describe()
df.info()

# %% [markdown]
# ## **Data Visualization**

# %%
import seaborn as sns
sns.pairplot(df)

# %% [markdown]
# ## **Data Preprocessing**

# %% [markdown]
# ## **Define Target Variable (y) and Feature Variables (X)**

# %%
y=df['Item_Outlet_Sales']

# %% [markdown]
# ## **Train Test Split**

# %% [markdown]
# ## **Modeling**

# %% [markdown]
# ## **Model Evaluation**

# %% [markdown]
# ## **Prediction**

# %% [markdown]
# ## **Explaination**
